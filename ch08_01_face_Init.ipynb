# %% [markdown]
# <a href="https://colab.research.google.com/github/DeuklyoungKo/MakeYourFirstGANWithPyTorch/blob/main/ch08_01_face_Init.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('./mount')
# Out:
# Mounted at ./mount

# %%
import h5py
import numpy
import matplotlib.pyplot as plt

# %%
# data file url : https://drive.google.com/file/d/1jXMKy-lYc4GBMeSmC6jtF1z3hwGWaAAN/view?usp=sharing
with h5py.File('mount/My Drive/Colab Notebooks/Deep Learning/MakeYourFirstGANWithPyTorch/celeba_dataset/celeba_aligned_small.h5py','r') as file_object:

  dataset = file_object['img_align_celeba']
  image = numpy.array(dataset['7.jpg'])
  plt.imshow(image, interpolation='none')
  pass

# %%
image.shape
# Out:
# (218, 178, 3)
